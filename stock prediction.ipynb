# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Stock.csv')

# %%
df.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
print(df.shape)
# Out:
# (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df[['Date','Open','Close']]
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))
2
df.set_index('Date',drop=True,inplace=True)
df.head(5)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001

# %%
 fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='black')
ax[0].set_xlabel('Year',size=20)
ax[0].set_ylabel('Price',size=20)
ax[0].legend()
ax[1].plot(df['Close'],label='Close',color='blue')
ax[1].set_xlabel('Year',size=20)
ax[1].set_ylabel('Price',size=20)
ax[1].legend()
fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
training_size = round(len(df) * 0.75)
training_size
# Out:
# 757

# %%
train_data = df[:training_size]
test_data = df[training_size:]
train_data.shape, test_data.shape
# Out:
# ((757, 2), (252, 2))

# %%
def create_sequence(dataset):
sequences = []
labels = []
start_idx = 0
for stop_idx in range(50,len(dataset)):
sequences.append(dataset.iloc[start_idx:stop_idx])
labels.append(dataset.iloc[stop_idx])
start_idx += 1
return (np.array(sequences),np.array(labels))
# Out:
#   File "<ipython-input-13-5722786af194>", line 2
#     sequences = []
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def create_sequence(dataset):
sequences = []
labels = []
start_idx = 0
for stop_idx in range(50,len(dataset)):
sequences.append(dataset.iloc[start_idx:stop_idx])
labels.append(dataset.iloc[stop_idx])
start_idx += 1
return (np.array(sequences),np.array(labels))
# Out:
#   File "<ipython-input-14-5722786af194>", line 2
#     sequences = []
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e07ed8fa6ce7> in <cell line: 1>()
# ----> 1 train_seq, train_label = create_sequence(train_data)
#       2 test_seq, test_label = create_sequence(test_data)
#       3 train_seq.shape, train_label.shape, test_seq.shape, test_label.shap
#
# NameError: name 'create_sequence' is not defined

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)):
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((707, 50, 2), (707, 2), (202, 50, 2), (202, 2))

# %%
 model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.
↪shape[1], train_seq.shape[2])))
model.add(Dropout(0.1))
model.add(LSTM(units=50))
model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam',␣
↪metrics=['mean_absolute_error'])
model.summary()
# Out:
#   File "<ipython-input-19-e5803a6eb999>", line 3
#     ↪shape[1], train_seq.shape[2])))
#     ^
# SyntaxError: invalid character '↪' (U+21AA)

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.
 shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam',
 metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq,
 test_label), verbose=1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 4s 58ms/step - loss: 0.0289 - mean_absolute_error: 0.1214 - val_loss: 0.0445 - val_mean_absolute_error: 0.1838
# Epoch 2/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0043 - mean_absolute_error: 0.0498 - val_loss: 0.0104 - val_mean_absolute_error: 0.0776
# Epoch 3/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0066 - val_mean_absolute_error: 0.0560
# Epoch 4/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 0.0063 - val_mean_absolute_error: 0.0553
# Epoch 5/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 0.0059 - val_mean_absolute_error: 0.0541
# Epoch 6/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0023 - mean_absolute_error: 0.0360 - val_loss: 0.0058 - val_mean_absolute_error: 0.0513
# Epoch 7/100
# 23/23 [==============================] - 1s 45ms/step - loss: 0.0023 - mean_absolute_error: 0.0367 - val_loss: 0.0053 - val_mean_absolute_error: 0.0496
# Epoch 8/100
# 23/23 [==============================] - 1s 44ms/step - loss: 0.0022 - mean_absolute_error: 0.0348 - val_loss: 0.0055 - val_mean_absolute_error: 0.0546
# Epoch 9/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0022 - mean_absolute_error: 0.0355 - val_loss: 0.0054 - val_mean_absolute_error: 0.0504
# Epoch 10/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 0.0046 - val_mean_absolute_error: 0.0467
# Epoch 11/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0059 - val_mean_absolute_error: 0.0532
# Epoch 12/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0046 - val_mean_absolute_error: 0.0457
# Epoch 13/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 0.0044 - val_mean_absolute_error: 0.0448
# Epoch 14/100
# 23/23 [==============================] - 1s 30ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 0.0045 - val_mean_absolute_error: 0.0450
# Epoch 15/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0366 - val_loss: 0.0058 - val_mean_absolute_error: 0.0623
# Epoch 16/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0019 - mean_absolute_error: 0.0320 - val_loss: 0.0045 - val_mean_absolute_error: 0.0456
# Epoch 17/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 0.0036 - val_mean_absolute_error: 0.0397
# Epoch 18/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0033 - val_mean_absolute_error: 0.0394
# Epoch 19/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0016 - mean_absolute_error: 0.0304 - val_loss: 0.0044 - val_mean_absolute_error: 0.0456
# Epoch 20/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 0.0032 - val_mean_absolute_error: 0.0389
# Epoch 21/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0017 - mean_absolute_error: 0.0302 - val_loss: 0.0031 - val_mean_absolute_error: 0.0366
# Epoch 22/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 0.0030 - val_mean_absolute_error: 0.0372
# Epoch 23/100
# 23/23 [==============================] - 1s 44ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0040 - val_mean_absolute_error: 0.0443
# Epoch 24/100
# 23/23 [==============================] - 1s 43ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 0.0028 - val_mean_absolute_error: 0.0358
# Epoch 25/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - val_loss: 0.0028 - val_mean_absolute_error: 0.0371
# Epoch 26/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0015 - mean_absolute_error: 0.0284 - val_loss: 0.0025 - val_mean_absolute_error: 0.0327
# Epoch 27/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0273 - val_loss: 0.0026 - val_mean_absolute_error: 0.0342
# Epoch 28/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0024 - val_mean_absolute_error: 0.0314
# Epoch 29/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0273 - val_loss: 0.0025 - val_mean_absolute_error: 0.0317
# Epoch 30/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 0.0023 - val_mean_absolute_error: 0.0309
# Epoch 31/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - val_loss: 0.0023 - val_mean_absolute_error: 0.0315
# Epoch 32/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - val_loss: 0.0023 - val_mean_absolute_error: 0.0303
# Epoch 33/100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0023 - val_mean_absolute_error: 0.0324
# Epoch 34/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 0.0024 - val_mean_absolute_error: 0.0342
# Epoch 35/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0012 - mean_absolute_error: 0.0262 - val_loss: 0.0024 - val_mean_absolute_error: 0.0335
# Epoch 36/100
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 0.0027 - val_mean_absolute_error: 0.0382
# Epoch 37/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 0.0020 - val_mean_absolute_error: 0.0283
# Epoch 38/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 0.0026 - val_mean_absolute_error: 0.0368
# Epoch 39/100
# 23/23 [==============================] - 1s 45ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 0.0026 - val_mean_absolute_error: 0.0378
# Epoch 40/100
# 23/23 [==============================] - 1s 45ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0019 - val_mean_absolute_error: 0.0273
# Epoch 41/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0010 - mean_absolute_error: 0.0239 - val_loss: 0.0018 - val_mean_absolute_error: 0.0270
# Epoch 42/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0010 - mean_absolute_error: 0.0236 - val_loss: 0.0018 - val_mean_absolute_error: 0.0271
# Epoch 43/100
# 23/23 [==============================] - 1s 37ms/step - loss: 9.8927e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0019 - val_mean_absolute_error: 0.0277
# Epoch 44/100
# 23/23 [==============================] - 1s 39ms/step - loss: 9.1162e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0018 - val_mean_absolute_error: 0.0270
# Epoch 45/100
# 23/23 [==============================] - 1s 34ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - val_loss: 0.0018 - val_mean_absolute_error: 0.0286
# Epoch 46/100
# 23/23 [==============================] - 1s 31ms/step - loss: 9.1787e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0019 - val_mean_absolute_error: 0.0284
# Epoch 47/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0018 - val_mean_absolute_error: 0.0274
# Epoch 48/100
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 0.0016 - val_mean_absolute_error: 0.0244
# Epoch 49/100
# 23/23 [==============================] - 1s 32ms/step - loss: 8.7786e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0015 - val_mean_absolute_error: 0.0246
# Epoch 50/100
# 23/23 [==============================] - 1s 33ms/step - loss: 8.3936e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0015 - val_mean_absolute_error: 0.0245
# Epoch 51/100
# 23/23 [==============================] - 1s 33ms/step - loss: 8.9620e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0018 - val_mean_absolute_error: 0.0301
# Epoch 52/100
# 23/23 [==============================] - 1s 32ms/step - loss: 8.4067e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0269
# Epoch 53/100
# 23/23 [==============================] - 1s 32ms/step - loss: 8.1010e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0015 - val_mean_absolute_error: 0.0238
# Epoch 54/100
# 23/23 [==============================] - 1s 39ms/step - loss: 7.3823e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0014 - val_mean_absolute_error: 0.0234
# Epoch 55/100
# 23/23 [==============================] - 1s 43ms/step - loss: 8.3593e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0020 - val_mean_absolute_error: 0.0315
# Epoch 56/100
# 23/23 [==============================] - 1s 44ms/step - loss: 7.9262e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0013 - val_mean_absolute_error: 0.0219
# Epoch 57/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.7742e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0013 - val_mean_absolute_error: 0.0218
# Epoch 58/100
# 23/23 [==============================] - 1s 31ms/step - loss: 8.7049e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0014 - val_mean_absolute_error: 0.0241
# Epoch 59/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.5705e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0015 - val_mean_absolute_error: 0.0260
# Epoch 60/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.1428e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0013 - val_mean_absolute_error: 0.0235
# Epoch 61/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.4819e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0013 - val_mean_absolute_error: 0.0225
# Epoch 62/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.9864e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0015 - val_mean_absolute_error: 0.0263
# Epoch 63/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.0915e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0013 - val_mean_absolute_error: 0.0237
# Epoch 64/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.8911e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0014 - val_mean_absolute_error: 0.0244
# Epoch 65/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.6744e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 66/100
# 23/23 [==============================] - 1s 31ms/step - loss: 6.4698e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 67/100
# 23/23 [==============================] - 1s 33ms/step - loss: 6.2602e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0011 - val_mean_absolute_error: 0.0209
# Epoch 68/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.4204e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0013 - val_mean_absolute_error: 0.0252
# Epoch 69/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.9525e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261
# Epoch 70/100
# 23/23 [==============================] - 1s 38ms/step - loss: 6.5392e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0012 - val_mean_absolute_error: 0.0218
# Epoch 71/100
# 23/23 [==============================] - 1s 44ms/step - loss: 6.9841e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0017 - val_mean_absolute_error: 0.0313
# Epoch 72/100
# 23/23 [==============================] - 1s 45ms/step - loss: 7.9763e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0011 - val_mean_absolute_error: 0.0206
# Epoch 73/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.6578e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 74/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.3342e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0013 - val_mean_absolute_error: 0.0224
# Epoch 75/100
# 23/23 [==============================] - 1s 31ms/step - loss: 6.1796e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 76/100
# 23/23 [==============================] - 1s 31ms/step - loss: 6.3345e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0011 - val_mean_absolute_error: 0.0210
# Epoch 77/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.9755e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309
# Epoch 78/100
# 23/23 [==============================] - 1s 32ms/step - loss: 7.1944e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0011 - val_mean_absolute_error: 0.0201
# Epoch 79/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.5887e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0010 - val_mean_absolute_error: 0.0196
# Epoch 80/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.7752e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0010 - val_mean_absolute_error: 0.0191
# Epoch 81/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.7031e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0011 - val_mean_absolute_error: 0.0207
# Epoch 82/100
# 23/23 [==============================] - 1s 31ms/step - loss: 6.5021e-04 - mean_absolute_error: 0.0183 - val_loss: 9.5083e-04 - val_mean_absolute_error: 0.0180
# Epoch 83/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.4432e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0013 - val_mean_absolute_error: 0.0251
# Epoch 84/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.7511e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0011 - val_mean_absolute_error: 0.0207
# Epoch 85/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.4675e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0011 - val_mean_absolute_error: 0.0200
# Epoch 86/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.8065e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 87/100
# 23/23 [==============================] - 1s 43ms/step - loss: 5.7489e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0010 - val_mean_absolute_error: 0.0194
# Epoch 88/100
# 23/23 [==============================] - 1s 46ms/step - loss: 5.6136e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 89/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.4452e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0010 - val_mean_absolute_error: 0.0194
# Epoch 90/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.3726e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0011 - val_mean_absolute_error: 0.0201
# Epoch 91/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.6074e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0012 - val_mean_absolute_error: 0.0235
# Epoch 92/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.4014e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0011 - val_mean_absolute_error: 0.0218
# Epoch 93/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.4098e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 94/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.3822e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 95/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.5005e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0021 - val_mean_absolute_error: 0.0373
# Epoch 96/100
# 23/23 [==============================] - 1s 32ms/step - loss: 6.7750e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0018 - val_mean_absolute_error: 0.0327
# Epoch 97/100
# 23/23 [==============================] - 1s 31ms/step - loss: 5.7936e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 98/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.3367e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0012 - val_mean_absolute_error: 0.0214
# Epoch 99/100
# 23/23 [==============================] - 1s 32ms/step - loss: 5.1234e-04 - mean_absolute_error: 0.0159 - val_loss: 9.6358e-04 - val_mean_absolute_error: 0.0189
# Epoch 100/100
# 23/23 [==============================] - 1s 33ms/step - loss: 5.4012e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0010 - val_mean_absolute_error: 0.0195

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 7ms/step
# array([[0.69162333, 0.68951476],
#        [0.6044005 , 0.6107978 ],
#        [0.60453445, 0.6061433 ],
#        [0.60171586, 0.6045601 ],
#        [0.6102159 , 0.6131001 ]], dtype=float32)

# %%
array([[0.6761785 , 0.6821655 ],
       [0.57702494, 0.5937154 ],
       [0.59286904, 0.6019453 ],
       [0.5903392 , 0.59944093],
       [0.59738994, 0.60556835]], dtype=float32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2389cca78713> in <cell line: 1>()
# ----> 1 array([[0.6761785 , 0.6821655 ],
#       2        [0.57702494, 0.5937154 ],
#       3        [0.59286904, 0.6019453 ],
#       4        [0.5903392 , 0.59944093],
#       5        [0.59738994, 0.60556835]], dtype=float32)
#
# NameError: name 'array' is not defined

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[550.9809 , 549.54675],
#        [510.99533, 513.50934],
#        [511.0567 , 511.37845],
#        [509.76456, 510.65363],
#        [513.66125, 514.56335]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-202:].copy(),
                          pd.
 DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                     index=df.iloc[-202:].index)], axis=1)

# %%
df_merge[['Open','Close']] = MMS.inverse_transform(df_merge[['Open','Close']])
df_merge.head()
# Out:
#                   Open       Close  open_predicted  close_predicted
# Date
# 2021-04-21  508.000000  508.899994      550.980896       549.546753
# 2021-04-22  513.820007  508.779999      510.995331       513.509338
# 2021-04-23  509.010010  505.549988      511.056702       511.378448
# 2021-04-26  506.760010  510.299988      509.764557       510.653625
# 2021-04-27  512.619995  505.549988      513.661255       514.563354

# %%
df_merge[['Open','open_predicted']].plot(figsize=(10,6),color=['purple','orange'])
plt.xticks(rotation=0)
plt.xlabel('Year',size=20)
plt.ylabel('Price',size=20)
plt.title('Actual Open Price vs Predicted Open Price',size=20)
plt.show()

# %%
df_merge[['Close','close_predicted']]. plot(figsize=(10,6),color=['darkgreen','red'])
plt.xticks(rotation=0)
plt.xlabel('Year',size=20)
plt.ylabel('Price',size=20)
plt.title('Actual close price vs Predicted close price',size=20)
plt.show()

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
index=pd.date_range(start=df_merge.
 index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                   Open       Close  open_predicted  close_predicted
# 2021-06-09  494.500000  485.809998      497.000549       497.892059
# 2021-06-10  487.170013  487.269989      490.954773       492.572388
# 2021-06-11  490.000000  488.769989      489.633301       491.119141
# 2021-06-14  489.679993  499.890015      491.618164       492.876953
# 2021-06-15  501.230011  491.899994      500.394989       500.843262
# 2021-06-16  495.000000  492.410004      497.807892       499.078339

# %%
upcoming_prediction = pd.DataFrame(columns=['Open','Close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
 up_pred = model.predict(curr_seq)
 upcoming_prediction.iloc[i] = up_pred
 curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
 curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
upcoming_prediction[['Open','Close']] = MMS.inverse_transform(upcoming_prediction[['Open','Close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'Open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'Open'],label='Upcoming Open␣Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=0)
ax.set_xlabel('Year',size=20)
ax.set_ylabel('Price',size=20)
ax.set_title('Upcoming Open price prediction',size=20)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'Close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'Close'],label='Upcoming close␣Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=0)
ax.set_xlabel('Year',size=20)
ax.set_ylabel('Price',size=20)
ax.set_title('Upcoming close price prediction',size=20)
ax.legend()
fig.show()
